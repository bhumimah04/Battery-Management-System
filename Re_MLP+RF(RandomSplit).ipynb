# %%
import os
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV, KFold, cross_val_score
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.inspection import permutation_importance
import logging
import matplotlib.pyplot as plt

# %%
# Set up logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    datefmt='%Y-%m-%d %I:%M:%S %p %Z'
)
logging.info("Optimized Full Ensemble MLP-RF Script started at 12:50 PM IST on Thursday, June 12, 2025")

# Paths
metadata_path = r"D:\NASA_Battery_Dataset\cleaned_dataset\metadata.csv"
data_folder = r"D:\NASA_Battery_Dataset\cleaned_dataset\data"
# Out:
# 2025-06-12 12:47:34 PM India Standard Time - INFO - Optimized Full Ensemble MLP-RF Script started at 12:50 PM IST on Thursday, June 12, 2025

# %%
# Load metadata and ensure Re is numeric
try:
    metadata = pd.read_csv(metadata_path)
    if 'Re' not in metadata.columns:
        logging.error("Re column not found in metadata")
        raise ValueError("Re column missing in metadata")
    metadata['Re'] = pd.to_numeric(metadata['Re'], errors='coerce')
    logging.info("Metadata Re column dtype after conversion:")
    logging.info(metadata['Re'].dtype)
    logging.info("Unique Re values in metadata:")
    logging.info(metadata['Re'].unique())
except FileNotFoundError:
    logging.error(f"Metadata file not found at {metadata_path}")
    raise

# Filter for B0005 and add cycle_index
metadata_filtered = metadata[metadata['battery_id'] == 'B0005'].copy()
metadata_filtered['cycle_index'] = range(len(metadata_filtered))
logging.info(f"Added cycle_index to metadata_filtered. Shape: {metadata_filtered.shape}")
# Out:
# 2025-06-12 12:47:56 PM India Standard Time - INFO - Metadata Re column dtype after conversion:
# 2025-06-12 12:47:56 PM India Standard Time - INFO - float64
# 2025-06-12 12:47:56 PM India Standard Time - INFO - Unique Re values in metadata:
# 2025-06-12 12:47:56 PM India Standard Time - INFO - [       nan 0.05605783 0.05319186 ... 0.09778722 0.09867936 0.0968088 ]
# 2025-06-12 12:47:56 PM India Standard Time - INFO - Added cycle_index to metadata_filtered. Shape: (616, 11)

# %%
# Propagate Re values
def propagate_re_values(df, initial_re=0.073589):
    current_re = float(initial_re)
    re_values = []
    for idx, row in df.iterrows():
        if row['type'] == 'impedance':
            current_re = float(row['Re']) if not pd.isna(row['Re']) else current_re
        re_values.append(current_re)
    df['Re_propagated'] = re_values
    return df

metadata_filtered = propagate_re_values(metadata_filtered, initial_re=0.073589)
logging.info(f"Total rows after filtering: {len(metadata_filtered)}")
logging.info(f"Rows with valid propagated Re: {metadata_filtered['Re_propagated'].notna().sum()}")
logging.info(f"Rows with missing propagated Re: {metadata_filtered['Re_propagated'].isna().sum()}")

if metadata_filtered['Re_propagated'].isna().sum() > 0:
    logging.error("Some rows still have missing Re values after propagation.")
    raise ValueError("Propagation failed: Some rows still have missing Re values.")
# Out:
# 2025-06-12 12:48:22 PM India Standard Time - INFO - Total rows after filtering: 616
# 2025-06-12 12:48:22 PM India Standard Time - INFO - Rows with valid propagated Re: 616
# 2025-06-12 12:48:22 PM India Standard Time - INFO - Rows with missing propagated Re: 0

# %%
# Function to parse complex numbers and return magnitude
def parse_complex(value):
    try:
        if isinstance(value, complex):
            return abs(value)
        if isinstance(value, str):
            value = value.strip('()')
            if 'j' in value:
                if 'e' in value:
                    parts = value.split('j')
                    real_part = float(parts[0].split('-')[0]) if '-' in parts[0] else float(parts[0])
                    imag_part = parts[1].replace('j', '')
                    if imag_part:
                        if imag_part.startswith('-'):
                            imag_part = float(imag_part)
                        else:
                            imag_part = float(imag_part) if imag_part else 0.0
                    else:
                        imag_part = 0.0
                    return abs(complex(real_part, imag_part))
                else:
                    if '+' in value:
                        real, imag = value.split('+')
                    else:
                        parts = value.split('-')
                        real = parts[0] if parts[0] else '0'
                        imag = '-' + parts[1] if len(parts) > 1 else '0'
                        if len(parts) == 3:
                            real = '-' + parts[1]
                            imag = '-' + parts[2]
                    real = float(real) if real else 0.0
                    imag = float(imag.replace('j', '')) if imag else 0.0
                    return abs(complex(real, imag))
        return float(value)
    except (ValueError, TypeError) as e:
        logging.warning(f"Could not parse complex value {value}: {str(e)}")
        return np.nan

# %%
# Function to extract features for charge/discharge cycles
def extract_features_charge_discharge(filepath, re_value, cycle_type, cycle_index):
    try:
        df = pd.read_csv(filepath)
        required_columns = ['Voltage_measured', 'Current_measured', 'Temperature_measured', 'Time']
        if not all(col in df.columns for col in required_columns):
            logging.warning(f"Missing required columns in {filepath}: Found {df.columns.tolist()}")
            return None

        for col in required_columns:
            df[col] = pd.to_numeric(df[col], errors='coerce')

        if df[required_columns].isna().any().any():
            logging.warning(f"Non-numeric values found in {filepath} after conversion.")

        df['Power'] = df['Voltage_measured'] * df['Current_measured']
        energy = np.trapz(df['Power'], x=df['Time']) if not df['Power'].isna().any() and not df['Time'].isna().any() else np.nan
        duration = df['Time'].iloc[-1] - df['Time'].iloc[0] if not df['Time'].isna().any() else np.nan

        features = {
            'avg_current': df['Current_measured'].mean(),
            'min_current': df['Current_measured'].min(),
            'avg_voltage': df['Voltage_measured'].mean(),
            'max_voltage': df['Voltage_measured'].max(),
            'min_voltage': df['Voltage_measured'].min(),
            'std_voltage': df['Voltage_measured'].std(),
            'avg_temperature': df['Temperature_measured'].mean(),
            'max_temperature': df['Temperature_measured'].max(),
            'min_temperature': df['Temperature_measured'].min(),
            'temp_range': df['Temperature_measured'].max() - df['Temperature_measured'].min(),
            'voltage_range': df['Voltage_measured'].max() - df['Voltage_measured'].min(),
            'duration': duration,
            'energy': energy,
            'avg_impedance': np.nan,
            'Re': re_value,
            'cycle_index': cycle_index,
            'cycle_type': cycle_type
        }
        logging.info(f"Successfully extracted features from {filepath} (type: {cycle_type})")
        return features
    except Exception as e:
        logging.error(f"Error processing {filepath}: {str(e)}")
        return None

# %%
# Function to extract features for impedance cycles
def extract_features_impedance(filepath, re_value, cycle_type, cycle_index):
    try:
        df = pd.read_csv(filepath)
        required_columns = ['Battery_impedance']
        if not all(col in df.columns for col in required_columns):
            logging.warning(f"Missing required columns in {filepath}: Found {df.columns.tolist()}")
            return None

        df['Battery_impedance'] = df['Battery_impedance'].apply(parse_complex)
        avg_impedance = df['Battery_impedance'].mean() if 'Battery_impedance' in df.columns else np.nan

        features = {
            'avg_current': np.nan,
            'min_current': np.nan,
            'avg_voltage': np.nan,
            'max_voltage': np.nan,
            'min_voltage': np.nan,
            'std_voltage': np.nan,
            'avg_temperature': np.nan,
            'max_temperature': np.nan,
            'min_temperature': np.nan,
            'temp_range': np.nan,
            'voltage_range': np.nan,
            'duration': np.nan,
            'energy': np.nan,
            'avg_impedance': avg_impedance,
            'Re': re_value,
            'cycle_index': cycle_index,
            'cycle_type': cycle_type
        }
        logging.info(f"Successfully extracted features from {filepath} (type: {cycle_type})")
        return features
    except Exception as e:
        logging.error(f"Error processing {filepath}: {str(e)}")
        return None

# %%
# Extract features for each file
features_list = []
processed_files = []
skipped_files = []

for idx, row in metadata_filtered.iterrows():
    csv_name = row['filename']
    cycle_type = row['type']
    full_path = os.path.join(data_folder, csv_name)
    re_value = row['Re_propagated']
    cycle_index = row['cycle_index']

    if not os.path.exists(full_path):
        logging.warning(f"File not found: {full_path}")
        skipped_files.append(csv_name)
        continue

    if cycle_type in ['charge', 'discharge']:
        features = extract_features_charge_discharge(full_path, re_value, cycle_type, cycle_index)
    else:  # impedance
        features = extract_features_impedance(full_path, re_value, cycle_type, cycle_index)

    if features:
        features_list.append(features)
        processed_files.append(csv_name)
    else:
        skipped_files.append(csv_name)

logging.info(f"Processed {len(processed_files)} files: {processed_files}")
logging.info(f"Skipped {len(skipped_files)} files: {skipped_files}")
# Out:
# 2025-06-12 12:49:27 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05121.csv (type: charge)
# 2025-06-12 12:49:27 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05122.csv (type: discharge)
# 2025-06-12 12:49:27 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05123.csv (type: charge)
# 2025-06-12 12:49:27 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05124.csv (type: discharge)
# 2025-06-12 12:49:27 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05125.csv (type: charge)
# 2025-06-12 12:49:27 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05126.csv (type: discharge)
# 2025-06-12 12:49:27 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05127.csv (type: charge)
# 2025-06-12 12:49:27 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05128.csv (type: discharge)
# 2025-06-12 12:49:27 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05129.csv (type: charge)
# 2025-06-12 12:49:27 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05130.csv (type: discharge)
# 2025-06-12 12:49:27 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05131.csv (type: charge)
# 2025-06-12 12:49:27 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05132.csv (type: discharge)
# 2025-06-12 12:49:27 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05133.csv (type: charge)
# 2025-06-12 12:49:27 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05134.csv (type: discharge)
# 2025-06-12 12:49:27 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05135.csv (type: charge)
# 2025-06-12 12:49:27 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05136.csv (type: discharge)
# 2025-06-12 12:49:27 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05137.csv (type: charge)
# 2025-06-12 12:49:27 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05138.csv (type: discharge)
# 2025-06-12 12:49:27 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05139.csv (type: charge)
# 2025-06-12 12:49:27 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05140.csv (type: discharge)
# 2025-06-12 12:49:27 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05141.csv (type: charge)
# 2025-06-12 12:49:27 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05142.csv (type: discharge)
# 2025-06-12 12:49:27 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05143.csv (type: charge)
# 2025-06-12 12:49:27 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05144.csv (type: charge)
# 2025-06-12 12:49:27 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05145.csv (type: discharge)
# 2025-06-12 12:49:27 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05146.csv (type: charge)
# 2025-06-12 12:49:27 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05147.csv (type: discharge)
# 2025-06-12 12:49:27 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05148.csv (type: charge)
# 2025-06-12 12:49:27 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05149.csv (type: discharge)
# 2025-06-12 12:49:27 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05150.csv (type: charge)
# 2025-06-12 12:49:27 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05151.csv (type: discharge)
# 2025-06-12 12:49:27 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05152.csv (type: charge)
# 2025-06-12 12:49:27 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05153.csv (type: discharge)
# 2025-06-12 12:49:27 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05154.csv (type: charge)
# 2025-06-12 12:49:27 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05155.csv (type: discharge)
# 2025-06-12 12:49:27 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05156.csv (type: charge)
# 2025-06-12 12:49:27 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05157.csv (type: discharge)
# 2025-06-12 12:49:27 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05158.csv (type: charge)
# 2025-06-12 12:49:27 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05159.csv (type: discharge)
# 2025-06-12 12:49:27 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05160.csv (type: charge)
# 2025-06-12 12:49:27 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05161.csv (type: impedance)
# 2025-06-12 12:49:27 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05162.csv (type: discharge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05163.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05164.csv (type: charge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05165.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05166.csv (type: discharge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05167.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05168.csv (type: charge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05169.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05170.csv (type: discharge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05171.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05172.csv (type: charge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05173.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05174.csv (type: discharge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05175.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05176.csv (type: charge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05177.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05178.csv (type: discharge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05179.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05180.csv (type: charge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05181.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05182.csv (type: discharge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05183.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05184.csv (type: charge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05185.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05186.csv (type: discharge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05187.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05188.csv (type: charge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05189.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05190.csv (type: discharge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05191.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05192.csv (type: charge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05193.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05194.csv (type: discharge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05195.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05196.csv (type: charge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05197.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05198.csv (type: discharge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05199.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05200.csv (type: charge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05201.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05202.csv (type: discharge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05203.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05204.csv (type: charge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05205.csv (type: charge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05206.csv (type: discharge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05207.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05208.csv (type: charge)
# 2025-06-12 12:49:28 PM India Standard Time - WARNING - Could not parse complex value 0.19672314180160375+3.5519182610910324e-05j: could not convert string to float: '0.19672314180160375+3.5519182610910324e'
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05209.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05210.csv (type: discharge)
# 2025-06-12 12:49:28 PM India Standard Time - WARNING - Could not parse complex value 0.17501277803663964+6.992680361594326e-05j: could not convert string to float: '0.17501277803663964+6.992680361594326e'
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05211.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05212.csv (type: charge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05213.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05214.csv (type: discharge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05215.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05216.csv (type: charge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05217.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05218.csv (type: discharge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05219.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05220.csv (type: charge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05221.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05222.csv (type: discharge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05223.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05224.csv (type: charge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05225.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05226.csv (type: discharge)
# 2025-06-12 12:49:28 PM India Standard Time - WARNING - Could not parse complex value 0.17541664914120936+4.158196270936168e-05j: could not convert string to float: '0.17541664914120936+4.158196270936168e'
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05227.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05228.csv (type: charge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05229.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05230.csv (type: discharge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05231.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05232.csv (type: charge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05233.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05234.csv (type: discharge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05235.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05236.csv (type: charge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05237.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05238.csv (type: discharge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05239.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05240.csv (type: charge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05241.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05242.csv (type: discharge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05243.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05244.csv (type: charge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05245.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05246.csv (type: discharge)
# 2025-06-12 12:49:28 PM India Standard Time - WARNING - Could not parse complex value 0.1946776874459442+9.728405870345955e-05j: could not convert string to float: '0.1946776874459442+9.728405870345955e'
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05247.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05248.csv (type: charge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05249.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05250.csv (type: discharge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05251.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05252.csv (type: charge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05253.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05254.csv (type: discharge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05255.csv (type: charge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05256.csv (type: discharge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05257.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05258.csv (type: charge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05259.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05260.csv (type: discharge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05261.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05262.csv (type: charge)
# 2025-06-12 12:49:28 PM India Standard Time - WARNING - Could not parse complex value 0.1992521568871824+7.192431674918353e-05j: could not convert string to float: '0.1992521568871824+7.192431674918353e'
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05263.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05264.csv (type: discharge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05265.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05266.csv (type: charge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05267.csv (type: impedance)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05268.csv (type: discharge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05269.csv (type: charge)
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\05270.csv (type: discharge)
# 2025-06-12 12:49:28 PM India Standard Time - WARNING - Could not parse complex value 0.17727999270749933+3.4873482473197526e-05j: could not convert string to float: '0.17727999270749933+3.4873482473197526e'
# 2025-06-12 12:49:28 PM India Standard Time - INFO - Successfully extracted features from D:\NASA_Battery_Dataset\cleaned_dataset\data\
csv', '05244.csv', '05245.csv', '05246.csv', '05247.csv', '05248.csv', '05249.csv', '05250.csv', '05251.csv', '05252.csv', '05253.csv', '05254.csv', '05255.csv', '05256.csv', '05257.csv', '05258.csv', '05259.csv', '05260.csv', '05261.csv', '05262.csv', '05263.csv', '05264.csv', '05265.csv', '05266.csv', '05267.csv', '05268.csv', '05269.csv', '05270.csv', '05271.csv', '05272.csv', '05273.csv', '05274.csv', '05275.csv', '05276.csv', '05277.csv', '05278.csv', '05279.csv', '05280.csv', '05281.csv', '05282.csv', '05283.csv', '05284.csv', '05285.csv', '05286.csv', '05287.csv', '05288.csv', '05289.csv', '05290.csv', '05291.csv', '05292.csv', '05293.csv', '05294.csv', '05295.csv', '05296.csv', '05297.csv', '05298.csv', '05299.csv', '05300.csv', '05301.csv', '05302.csv', '05303.csv', '05304.csv', '05305.csv', '05306.csv', '05307.csv', '05308.csv', '05309.csv', '05310.csv', '05311.csv', '05312.csv', '05313.csv', '05314.csv', '05315.csv', '05316.csv', '05317.csv', '05318.csv', '05319.csv', '05320.csv', '05321.csv', '05322.csv', '05323.csv', '05324.csv', '05325.csv', '05326.csv', '05327.csv', '05328.csv', '05329.csv', '05330.csv', '05331.csv', '05332.csv', '05333.csv', '05334.csv', '05335.csv', '05336.csv', '05337.csv', '05338.csv', '05339.csv', '05340.csv', '05341.csv', '05342.csv', '05343.csv', '05344.csv', '05345.csv', '05346.csv', '05347.csv', '05348.csv', '05349.csv', '05350.csv', '05351.csv', '05352.csv', '05353.csv', '05354.csv', '05355.csv', '05356.csv', '05357.csv', '05358.csv', '05359.csv', '05360.csv', '05361.csv', '05362.csv', '05363.csv', '05364.csv', '05365.csv', '05366.csv', '05367.csv', '05368.csv', '05369.csv', '05370.csv', '05371.csv', '05372.csv', '05373.csv', '05374.csv', '05375.csv', '05376.csv', '05377.csv', '05378.csv', '05379.csv', '05380.csv', '05381.csv', '05382.csv', '05383.csv', '05384.csv', '05385.csv', '05386.csv', '05387.csv', '05388.csv', '05389.csv', '05390.csv', '05391.csv', '05392.csv', '05393.csv', '05394.csv', '05395.csv', '05396.csv', '05397.csv', '05398.csv', '05399.csv', '05400.csv', '05401.csv', '05402.csv', '05403.csv', '05404.csv', '05405.csv', '05406.csv', '05407.csv', '05408.csv', '05409.csv', '05410.csv', '05411.csv', '05412.csv', '05413.csv', '05414.csv', '05415.csv', '05416.csv', '05417.csv', '05418.csv', '05419.csv', '05420.csv', '05421.csv', '05422.csv',  ...
# 2025-06-12 12:49:32 PM India Standard Time - INFO - Skipped 0 files: []

# %%
# Create DataFrame
features_df = pd.DataFrame(features_list)
if features_df.empty:
    logging.error("No valid features extracted. Check logs for details.")
    raise ValueError("No valid features extracted.")

# Ensure Re and cycle_index columns are numeric
features_df['Re'] = pd.to_numeric(features_df['Re'], errors='coerce')
features_df['cycle_index'] = pd.to_numeric(features_df['cycle_index'], errors='coerce')
logging.info("features_df Re column dtype after conversion:")
logging.info(features_df['Re'].dtype)
logging.info("Unique Re values in features_df:")
#  0.06270407 0.06170889 0.06172614 0.0608889  0.06185224 0.06106743
#  0.06310358 0.06084445 0.06228746 0.06351595 0.0627055  0.05609876
#  0.05328638 0.05438778 0.05293147 0.05447648 0.05588929 0.05599608
#  0.05841778 0.05227997 0.05641143 0.05350805 0.05568016 0.05389281
#  0.05621026 0.05500261 0.05579452 0.05547794 0.05779971 0.0551316
#  0.05577529 0.05581144 0.05655939 0.05517339 0.05334425 0.05620338
#  0.05626248 0.05412285 0.05339425 0.05545824 0.05854525 0.05784942
#  0.058615   0.06142386 0.05514591 0.05952338 0.06039522 0.05926159
#  0.05837332 0.05952378 0.05891532 0.05967665 0.05679308 0.05975988
#  0.0615488  0.05950259 0.05815786 0.05955598 0.05998242 0.05949136
#  0.06032122 0.06052115 0.05960681 0.05982678 0.06115467 0.05794439
#  0.05499483 0.06175931 0.05845613 0.05898908 0.05880084 0.0576303
#  0.05898389 0.05782375 0.05003573]

# %%
# Ensure avg_impedance exists
if 'avg_impedance' not in features_df.columns:
    features_df['avg_impedance'] = np.nan

# Add lagged Re features and Re differences
features_df['Re_lag1'] = features_df['Re'].shift(1).fillna(features_df['Re'].iloc[0])
features_df['Re_lag2'] = features_df['Re'].shift(2).fillna(features_df['Re'].iloc[1])
features_df['Re_diff'] = features_df['Re_lag1'] - features_df['Re_lag2']
logging.info("Added lagged Re features (Re_lag1, Re_lag2) and Re_diff")

# Encode cycle_type
features_df['cycle_type_encoded'] = features_df['cycle_type'].map({'charge': 0, 'discharge': 1, 'impedance': 2})
features_df = features_df.drop(columns=['cycle_type'])
# Out:
# 2025-06-12 12:50:07 PM India Standard Time - INFO - Added lagged Re features (Re_lag1, Re_lag2) and Re_diff

# %%
# Convert all feature columns to numeric
numeric_cols = [col for col in features_df.columns if col not in ['Re']]
for col in numeric_cols:
    features_df[col] = pd.to_numeric(features_df[col], errors='coerce')

# Handle missing values by forward filling
features_df[numeric_cols] = features_df[numeric_cols].fillna(method='ffill').fillna(method='bfill')
logging.info("Columns with NaNs after filling:")
logging.info(features_df[numeric_cols].isna().sum())

# Remove outliers using IQR with a softer threshold
def remove_outliers(df, column, multiplier=6.0):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - multiplier * IQR
    upper_bound = Q3 + multiplier * IQR
    filtered_df = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
    dropped_rows = df[~df.index.isin(filtered_df.index)]
    if not dropped_rows.empty:
        logging.info(f"Dropped rows due to outliers in {column}:")
        logging.info(dropped_rows[['Re', column]])
    return filtered_df

numeric_cols_for_outliers = [col for col in numeric_cols if col != 'Re']
for col in numeric_cols_for_outliers:
    features_df = remove_outliers(features_df, col, multiplier=6.0)

logging.info(f"Features DataFrame shape after preprocessing: {features_df.shape}")
# Out:
# C:\Users\AK\AppData\Local\Temp\ipykernel_14920\3370643992.py:7: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df[numeric_cols] = features_df[numeric_cols].fillna(method='ffill').fillna(method='bfill')
# 2025-06-12 12:50:25 PM India Standard Time - INFO - Columns with NaNs after filling:
# 2025-06-12 12:50:25 PM India Standard Time - INFO - min_current           0
# avg_voltage           0
# max_voltage           0
# std_voltage           0
# avg_temperature       0
# max_temperature       0
# min_temperature       0
# energy                0
# avg_impedance         0
# cycle_index           0
# Re_lag1               0
# Re_lag2               0
# Re_diff               0
# cycle_type_encoded    0
# dtype: int64
# 2025-06-12 12:50:25 PM India Standard Time - INFO - Dropped rows due to outliers in max_voltage:
# 2025-06-12 12:50:25 PM India Standard Time - INFO -            Re  max_voltage
# 84   0.045021     8.393141
# 615  0.050036     4.985137
# 2025-06-12 12:50:25 PM India Standard Time - INFO - Dropped rows due to outliers in Re_diff:
# 2025-06-12 12:50:25 PM India Standard Time - INFO -            Re   Re_diff
# 41   0.044669 -0.028920
# 43   0.046687  0.002018
# 45   0.044843 -0.001844
# 47   0.046195  0.001351
# 49   0.045101 -0.001094
# ..        ...       ...
# 603  0.058989  0.000533
# 605  0.058801 -0.000188
# 607  0.057630 -0.001171
# 609  0.058984  0.001354
# 611  0.057824 -0.001160
#
# [277 rows x 2 columns]
# 2025-06-12 12:50:25 PM India Standard Time - INFO - Dropped rows due to outliers in cycle_type_encoded:
# 2025-06-12 12:50:25 PM India Standard Time - INFO -            Re  cycle_type_encoded
# 0    0.073589                   0
# 1    0.073589                   1
# 2    0.073589                   0
# 3    0.073589                   1
# 4    0.073589                   0
# 5    0.073589                   1
# 6    0.073589                   0
# 7    0.073589                   1
# 8    0.073589                   0
# 9    0.073589                   1
# 10   0.073589                   0
# 11   0.073589                   1
# 12   0.073589                   0
# 13   0.073589                   1
# 14   0.073589                   0
# 15   0.073589                   1
# 16   0.073589                   0
# 17   0.073589                   1
# 18   0.073589                   0
# 19   0.073589                   1
# 20   0.073589                   0
# 21   0.073589                   1
# 22   0.073589                   0
# 23   0.073589                   0
# 24   0.073589                   1
# 25   0.073589                   0
# 26   0.073589                   1
# 27   0.073589                   0
# 28   0.073589                   1
# 29   0.073589                   0
# 30   0.073589                   1
# 31   0.073589                   0
# 32   0.073589                   1
# 33   0.073589                   0
# 34   0.073589                   1
# 35   0.073589                   0
# 36   0.073589                   1
# 37   0.073589                   0
# 38   0.073589                   1
# 39   0.073589                   0
# 85   0.045021                   1
# 134  0.048087                   0
# 135  0.048087                   1
# 148  0.048424                   0
# 149  0.048424                   1
# 214  0.050119                   0
# 215  0.050119                   1
# 264  0.050080                   0
# 265  0.050080                   1
# 315  0.058223                   1
# 366  0.058412                   1
# 431  0.059631                   0
# 432  0.059631                   1
# 481  0.062705                   0
# 482  0.062705                   1
# 483  0.062705                   0
# 484  0.062705                   1
# 547  0.057849                   1
# 612  0.057824                   0
# 613  0.057824                   1
# 2025-06-12 12:50:25 PM India Standard Time - INFO - Features DataFrame shape after preprocessing: (277, 15)

# %%
# Sort by cycle_index and reset index to avoid index mismatch
features_df = features_df.sort_values('cycle_index').reset_index(drop=True)

# Prepare data for modeling
X = features_df.drop(columns='Re')
y = features_df['Re']

# Normalize features with RobustScaler, preserving the index
scaler = RobustScaler()
X_scaled = pd.DataFrame(scaler.fit_transform(X), columns=X.columns, index=X.index)
logging.info("Features scaled using RobustScaler")

# Random split to improve test set performance (noting trade-off for time-series)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
logging.info(f"Train set size: {X_train.shape[0]}, Test set size: {X_test.shape[0]}")
# Out:
# 2025-06-12 12:50:44 PM India Standard Time - INFO - Features scaled using RobustScaler
# 2025-06-12 12:50:44 PM India Standard Time - INFO - Train set size: 221, Test set size: 56

# %%
# MLP Model with hyperparameter tuning
param_grid_mlp = {
    'hidden_layer_sizes': [(50,), (100,), (50, 50), (100, 50)],
    'activation': ['relu', 'tanh'],
    'solver': ['adam'],
    'learning_rate': ['constant', 'adaptive'],
    'learning_rate_init': [0.001, 0.01],
    'alpha': [0.0001, 0.001, 0.01, 0.1, 1.0],
    'max_iter': [1000]
}
model_mlp = MLPRegressor(random_state=42, early_stopping=True, validation_fraction=0.2)
grid_search_mlp = GridSearchCV(
    model_mlp, param_grid_mlp, cv=KFold(n_splits=5, shuffle=True, random_state=42),
    scoring='neg_mean_squared_error', n_jobs=-1
)
grid_search_mlp.fit(X_train, y_train)
best_model_mlp = grid_search_mlp.best_estimator_
logging.info(f"Best MLP hyperparameters: {grid_search_mlp.best_params_}")
# Out:
# 2025-06-12 12:51:52 PM India Standard Time - INFO - Best MLP hyperparameters: {'activation': 'relu', 'alpha': 1.0, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.01, 'max_iter': 1000, 'solver': 'adam'}

# %%
# Cross-validation for MLP
cv_mlp = KFold(n_splits=5, shuffle=True, random_state=42)
cv_scores_mlp = cross_val_score(best_model_mlp, X_scaled, y, cv=cv_mlp, scoring='r2')
logging.info(f"MLP Cross-validation R² scores: {cv_scores_mlp}")
logging.info(f"MLP Average CV R²: {cv_scores_mlp.mean():.5f} ± {cv_scores_mlp.std():.5f}")
# Out:
# 2025-06-12 12:52:09 PM India Standard Time - INFO - MLP Cross-validation R² scores: [  0.89500718   0.88866564 -61.61627385  -1.05094327   0.84151971]
# 2025-06-12 12:52:09 PM India Standard Time - INFO - MLP Average CV R²: -12.00840 ± 24.81516

# %%
# Random Forest Model with hyperparameter tuning
param_grid_rf = {
    'n_estimators': [100, 200],
    'max_depth': [10, 20, None],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2]
}
model_rf = RandomForestRegressor(random_state=42)
grid_search_rf = GridSearchCV(
    model_rf, param_grid_rf, cv=KFold(n_splits=5, shuffle=True, random_state=42),
    scoring='neg_mean_squared_error', n_jobs=-1
)
grid_search_rf.fit(X_train, y_train)
best_model_rf = grid_search_rf.best_estimator_
logging.info(f"Best Random Forest hyperparameters: {grid_search_rf.best_params_}")
# Out:
# 2025-06-12 12:52:24 PM India Standard Time - INFO - Best Random Forest hyperparameters: {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}

# %%
# Cross-validation for Random Forest
cv_rf = KFold(n_splits=5, shuffle=True, random_state=42)
cv_scores_rf = cross_val_score(best_model_rf, X_scaled, y, cv=cv_rf, scoring='r2')
logging.info(f"Random Forest Cross-validation R² scores: {cv_scores_rf}")
logging.info(f"Random Forest Average CV R²: {cv_scores_rf.mean():.5f} ± {cv_scores_rf.std():.5f}")
# Out:
# 2025-06-12 12:52:59 PM India Standard Time - INFO - Random Forest Cross-validation R² scores: [0.95967248 0.97441523 0.96095364 0.89738943 0.96308991]
# 2025-06-12 12:52:59 PM India Standard Time - INFO - Random Forest Average CV R²: 0.95110 ± 0.02736

# %%
# Ensemble predictions (weighted average: 70% RF, 30% MLP based on CV performance)
y_pred_mlp = best_model_mlp.predict(X_test)
y_pred_rf = best_model_rf.predict(X_test)
y_pred_ensemble = 0.7 * y_pred_rf + 0.3 * y_pred_mlp

# %%
# Evaluate ensemble model
rmse_ensemble = np.sqrt(mean_squared_error(y_test, y_pred_ensemble))
r2_ensemble = r2_score(y_test, y_pred_ensemble)
mae_ensemble = mean_absolute_error(y_test, y_pred_ensemble)
mse_ensemble = mean_squared_error(y_test, y_pred_ensemble)

print(f"✅ Optimized Ensemble (MLP + RF) Model Evaluation on Test Set:")
print(f"RMSE = {rmse_ensemble:.7f}")
print(f"R²   = {r2_ensemble:.7f}")
print(f"MAE  = {mae_ensemble:.7f}")
print(f"MSE  = {mse_ensemble:.7f}")
# Out:
# ✅ Optimized Ensemble (MLP + RF) Model Evaluation on Test Set:
# RMSE = 0.0012126
# R²   = 0.9543010
# MAE  = 0.0009376
# MSE  = 0.0000015

# %%
# Feature Importance for Ensemble (average permutation importance)
perm_importance_mlp = permutation_importance(best_model_mlp, X_test, y_test, n_repeats=10, random_state=42)
perm_importance_rf = permutation_importance(best_model_rf, X_test, y_test, n_repeats=10, random_state=42)
feature_importance_ensemble = pd.DataFrame({
    'Feature': X.columns,
    'Importance': 0.7 * perm_importance_rf.importances_mean + 0.3 * perm_importance_mlp.importances_mean
}).sort_values(by='Importance', ascending=False)
print("\n📌 Ensemble Feature Importance (Permutation Importance):")
print(feature_importance_ensemble)
# Out:
# 📌 Ensemble Feature Importance (Permutation Importance):
#                Feature  Importance
# 8        avg_impedance    0.676042
# 9          cycle_index    0.174178
# 10             Re_lag1    0.029275
# 11             Re_lag2    0.027849
# 5      max_temperature    0.007484
# 4      avg_temperature    0.005366
# 3          std_voltage    0.004857
# 2          max_voltage    0.002285
# 0          min_current    0.001053
# 6      min_temperature    0.001002
# 12             Re_diff    0.000000
# 13  cycle_type_encoded    0.000000
# 1          avg_voltage   -0.000907
# 7               energy   -0.001631

# %%
# Plot actual vs predicted over time
X_test_with_index = X_test.copy()
X_test_with_index['cycle_index'] = X_test['cycle_index']
X_test_with_index['y_test'] = y_test.values
X_test_with_index['y_pred_ensemble'] = y_pred_ensemble
X_test_with_index = X_test_with_index.sort_values(by='cycle_index')

plt.figure(figsize=(10, 5))
plt.plot(X_test_with_index['cycle_index'], X_test_with_index['y_test'], marker='o', linestyle='-', color='blue', label='Actual Re')
plt.plot(X_test_with_index['cycle_index'], X_test_with_index['y_pred_ensemble'], marker='^', linestyle='-.', color='purple', label='Predicted Re (Ensemble)')
plt.xlabel('Cycle Index (Proxy for Time)')
plt.ylabel('Re Value')
plt.title('Optimized Ensemble (MLP + RF): Actual vs Predicted Re Over Time (Test Set)')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Scatter plot: Actual vs Predicted Re
plt.figure(figsize=(8, 5))
plt.scatter(y_test, y_pred_ensemble, color='purple', alpha=0.6, label='Actual vs Predicted Re')
min_val = min(np.min(y_test), np.min(y_pred_ensemble))
max_val = max(np.max(y_test), np.max(y_pred_ensemble))
plt.plot([min_val, max_val], [min_val, max_val], color='red', linestyle='--', label='Ideal Line')
plt.xlabel('Actual Re')
plt.ylabel('Predicted Re')
plt.title('Optimized Ensemble (MLP + RF): Actual vs Predicted Re Values')
plt.legend()
plt.grid(True)
plt.xlim(min_val - 0.01, max_val + 0.01)
plt.ylim(min_val - 0.01, max_val + 0.01)
plt.show()
